# %%
import os
import sys
from dotenv import find_dotenv,load_dotenv
load_dotenv(find_dotenv())
src_path = os.environ.get('PROJECT_SRC')
os.chdir(src_path)

# %%
#import meteostat_tempreature as mt       # if you wanna run the weather extraction, uncomment this line of code
import matplotlib.pyplot as plt,geopandas as gpd,shapefile,pandas as pd 
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist

plt.style.use('ggplot')
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature

# %% [markdown]
# Visualise the local authorities considered to model the aggregated heat demands

# %%
#set the file path
fp = 'data/LA_UK/LAD_MAY_2022_UK_BFE_V3.shp'
# Read file using gpd.read_file()
LA_UK = gpd.read_file(fp)

# %%
LA_UK
# Out:
#        LAD22CD               LAD22NM   BNG_E   BNG_N     LONG      LAT  \
# 0    E06000001            Hartlepool  447160  531474 -1.27018  54.6761
# 1    E06000002         Middlesbrough  451141  516887 -1.21099  54.5447
# 2    E06000003  Redcar and Cleveland  464361  519597 -1.00608  54.5675
# 3    E06000004      Stockton-on-Tees  444940  518183 -1.30664  54.5569
# 4    E06000005            Darlington  428029  515648 -1.56835  54.5353
# ..         ...                   ...     ...     ...      ...      ...
# 369  W06000020               Torfaen  327459  200480 -3.05101  51.6984
# 370  W06000021         Monmouthshire  337812  209231 -2.90280  51.7783
# 371  W06000022               Newport  337897  187432 -2.89769  51.5823
# 372  W06000023                 Powys  302329  273255 -3.43531  52.3486
# 373  W06000024        Merthyr Tydfil  305916  206424 -3.36425  51.7486
#
#                                  GlobalID  \
# 0    2efc9848-300e-4ef3-a36e-58d6856b9817
# ...

# %% [markdown]
# Cluster the local authorities to 29 regions which can mode the aggregate heat demand for the district heating. For the clustering purpose the KMeans algorithm is implemented and the heat nodes are used as a centroid for the KMeans clustering

# %%
# find the coordinates for local authorities and the coordinates of the centroid
#modell='reduced'
modell='zonal'

LA_UK_=[]
for i in range(len(LA_UK)):
    LA_UK_coordinates=LA_UK_.append([LA_UK.iloc[i]['LAT'],LA_UK.iloc[i]['LONG']])
LA_UK_coordinates=np.asarray(LA_UK_)

if modell=='zonal':
    df_network = pd.read_csv('data/buses_ZM.csv')
elif modell=='reduced':
    df_network = pd.read_csv('data/buses.csv')

gb_nodes=[]
for i in range(len(df_network[:29])):
    heat_node_centroids=gb_nodes.append([df_network.iloc[i]['y'],df_network.iloc[i]['x']])
heat_node_centroids=np.array(gb_nodes)

# %% [markdown]
# Remove the Orkeny islands, the northern ireland local authorities

# %%
condition = (LA_UK['LAD22NM'] == 'Orkney Islands')  # Specify the condition
LA_UK = LA_UK.drop(LA_UK[condition].index)

condition = (LA_UK['LAD22NM'] == 'Shetland Islands')  # Specify the condition
LA_UK = LA_UK.drop(LA_UK[condition].index)

# exclude the Northern ireland nodes, since we are modelling for GB
for i in range(11):
    condition = (LA_UK['LAD22CD'] == 'N0900000'+str(i+1))  # Specify the condition
    LA_UK = LA_UK.drop(LA_UK[condition].index)
LA_UK = LA_UK.drop(LA_UK[(LA_UK['LAD22CD'] == 'N09000010')].index)
LA_UK = LA_UK.drop(LA_UK[(LA_UK['LAD22CD'] == 'N09000011')].index)
# exclude the isle isalnds
LA_UK = LA_UK.drop(LA_UK[(LA_UK['LAD22NM'] == 'Na h-Eileanan Siar')].index)

# %% [markdown]
# Using KMeans clustering for the Geopands dataframe based on the geometry points

# %%
# Converting the geometry column in a GeoPandas DataFrame from polygons to geographic latitude and longitude coordinates (points),using the centroid property of the polygons
LA_UK_points = LA_UK.copy()

# Convert the 'geometry' column to centroid points
LA_UK_points['geometry'] = LA_UK_points['geometry'].centroid

# Convert the geometry column to longitude and latitude coordinates
LA_UK_points = LA_UK_points.set_geometry('geometry')
LA_UK_points = LA_UK_points.to_crs('EPSG:4326')

# %%
LA_UK_points
# Out:
#        LAD22CD               LAD22NM   BNG_E   BNG_N     LONG      LAT  \
# 0    E06000001            Hartlepool  447160  531474 -1.27018  54.6761
# 1    E06000002         Middlesbrough  451141  516887 -1.21099  54.5447
# 2    E06000003  Redcar and Cleveland  464361  519597 -1.00608  54.5675
# 3    E06000004      Stockton-on-Tees  444940  518183 -1.30664  54.5569
# 4    E06000005            Darlington  428029  515648 -1.56835  54.5353
# ..         ...                   ...     ...     ...      ...      ...
# 369  W06000020               Torfaen  327459  200480 -3.05101  51.6984
# 370  W06000021         Monmouthshire  337812  209231 -2.90280  51.7783
# 371  W06000022               Newport  337897  187432 -2.89769  51.5823
# 372  W06000023                 Powys  302329  273255 -3.43531  52.3486
# 373  W06000024        Merthyr Tydfil  305916  206424 -3.36425  51.7486
#
#                                  GlobalID                   geometry
# ...

# %% [markdown]
# Apply the KMeans Clustering to find the clusters in the local authroity

# %%
points = LA_UK_points['geometry'].apply(lambda geom: (geom.y, geom.x))
coordinates = np.array(list(points))
centroids=heat_node_centroids
kmeans = KMeans(n_clusters=len(centroids), init=centroids, n_init=1)
clusters = kmeans.fit_predict(coordinates)

LA_UK_points['cluster'] = clusters

LA_UK_points.plot(column='cluster', categorical=True, legend=True, figsize=(15, 59))
plt.legend(bbox_to_anchor=(1.0, 1.0))
plt.show()
# Out:
# C:\Users\salene\Anaconda3\envs\REMA\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Define a color map for the clusters
num_clusters = len(np.unique(clusters))
color_map = plt.get_cmap('tab20', num_clusters)
# Create convex hulls for each cluster
convex_hulls = LA_UK_points.groupby('cluster')['geometry'].apply(lambda x: x.unary_union.convex_hull)

# Plot the shaded convex hulls and scatter points for each cluster
fig, ax = plt.subplots(figsize=(30, 30))
ax = fig.add_subplot(1, 1, 1,
                     projection=ccrs.PlateCarree())

extent = [-8.09782, 2.40511, 60, 49.5]
ax.set_extent(extent)
ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cartopy.feature.LAND)
for cluster_label, convex_hull in convex_hulls.items():
    cluster_points = LA_UK_points[LA_UK_points['cluster'] == cluster_label]
    cluster_points.plot(ax=ax, color=color_map(cluster_label), label=f'Cluster {cluster_label}', markersize=10)
    gpd.GeoSeries(convex_hull).plot(ax=ax, facecolor=color_map(cluster_label), alpha=1, linewidth=0)
plt.legend(bbox_to_anchor=(1.0, 1.0))
plt.show()

# %%
cluster_label=4
clustered_elements=LA_UK_points[LA_UK_points['cluster']==cluster_label]
print(clustered_elements)
# Out:
#        LAD22CD                 LAD22NM   BNG_E   BNG_N     LONG      LAT  \
# 29   E06000032                   Luton  508606  222559 -0.42319  51.8910
# 36   E06000039                  Slough  498920  179246 -0.57617  51.5035
# 37   E06000040  Windsor and Maidenhead  492079  176541 -0.67541  51.4803
# 39   E06000042           Milton Keynes  486408  242308 -0.74070  52.0724
# 40   E06000043       Brighton and Hove  530279  106850 -0.15079  50.8465
# ..         ...                     ...     ...     ...      ...      ...
# 304  E09000029                  Sutton  527356  163640 -0.17227  51.3576
# 305  E09000030           Tower Hamlets  536340  181452 -0.03647  51.5155
# 306  E09000031          Waltham Forest  537327  190277 -0.01881  51.5946
# 307  E09000032              Wandsworth  525151  174138 -0.20023  51.4524
# 308  E09000033             Westminster  528268  180870 -0.15295  51.5122
#
#                                  GlobalID                   geometry  cluster
# ...

# %%
# Group the dataframe by the 'cluster' column
grouped_gdf = LA_UK_points.groupby('cluster')

# %%
grouped_gdf

# %%
# Group the dataframe by the 'cluster' column
grouped_gdf = LA_UK_points.groupby('cluster')

# Iterate over each cluster
for cluster, cluster_data in grouped_gdf:
    # Access the elements in the cluster
    elements_in_cluster = cluster_data['LAD22NM'].tolist()
    
    # Print the cluster ID and the elements
    print(f"Cluster '{cluster}': {elements_in_cluster}")
# Out:
# Cluster '0': ['Kingston upon Hull, City of', 'East Riding of Yorkshire', 'North East Lincolnshire', 'North Lincolnshire', 'Rutland', 'Peterborough', 'North Northamptonshire', 'Fenland', 'Huntingdonshire', 'Melton', 'Boston', 'East Lindsey', 'Lincoln', 'North Kesteven', 'South Holland', 'South Kesteven', 'West Lindsey']
# Cluster '1': ['Leicester', 'West Northamptonshire', 'South Derbyshire', 'Cheltenham', 'Cotswold', 'Tewkesbury', 'Blaby', 'Harborough', 'Hinckley and Bosworth', 'North West Leicestershire', 'Oadby and Wigston', 'Cherwell', 'West Oxfordshire', 'Cannock Chase', 'East Staffordshire', 'Lichfield', 'South Staffordshire', 'Stafford', 'Tamworth', 'North Warwickshire', 'Nuneaton and Bedworth', 'Rugby', 'Stratford-on-Avon', 'Warwick', 'Bromsgrove', 'Malvern Hills', 'Redditch', 'Worcester', 'Wychavon', 'Wyre Forest', 'Birmingham', 'Coventry', 'Dudley', 'Sandwell', 'Solihull', 'Walsall', 'Wolverhampton']
# ...

# %% [markdown]
# Import the heat demand estimation modules

# %%
#import heat_demand_estimation_clustered_LAs as HDEC

# %%
if modell=='reduced':
    heat_node=[
    'beauly',
    'peterhead',
    'errochty',
    'denny_bonny',
    'neilston',
    'strathaven', 
    'torness',
    'eccles',
    'harker',
    'stella_west',
    'penwortham',
    'deeside',
    'daines',
    'thornton_drax_eggborough',
    'keadby',
    'ratcliffe',
    'feckenham',
    'walpole',
    'bramford',
    'pelham',
    'sundon_east_claydon',
    'melksham',
    'bramley',
    'london',
    'kemsley',
    'sellindge',
    'lovedean',
    's_w_penisula'
          ]
    ndgs=[
        110743,
        222705,
        113905,
        573685,
        755206,
        276418,
        429266,
        159916,
        254232,
        1053267,
        1707778,
        356799,
        2112187,
        1532347,
        328850,
        633434,
        1305544,
        2450407,
        496966,
        864598,
        786100,
        1223456,
        1838244,
        1210484,
        4321906,
        1110260,
        246191,
        1390928,
        956221,
    ]
    
elif modell=='zonal':
    heat_node=[
    'Z10',
    'Z11',
    'Z12',
    'Z13',
    'Z14',
    'Z15', 
    'Z16',
    'Z17',
    'Z1_1',
    'Z1_2',
    'Z1_3',
    'Z1_4',
    'Z2',
    'Z3',
    'Z4',
    'Z5',
    'Z6',
    'Z7',
    'Z8',
    'Z9'
    ]

# %%
modell
# Out:
# 'zonal'

# %%
len(heat_node)
# Out:
# 20

# %%
num_clusters
# Out:
# 20

# %%
# Accessing elements in a specific cluster label
cluster_elements = LA_UK_points[LA_UK_points['cluster'] == 19]
cluster_elements
# Out:
#        LAD22CD                    LAD22NM   BNG_E   BNG_N     LONG      LAT  \
# 5    E06000006                     Halton  354246  382146 -2.68853  53.3342
# 6    E06000007                 Warrington  362744  388456 -2.56167  53.3916
# 7    E06000008      Blackburn with Darwen  369490  422806 -2.46360  53.7008
# 8    E06000009                  Blackpool  332819  436635 -3.02199  53.8216
# 19   E06000020         Telford and Wrekin  367035  313057 -2.48941  52.7142
# 20   E06000021             Stoke-on-Trent  389438  346652 -2.15888  53.0171
# 45   E06000049              Cheshire East  380510  363462 -2.29299  53.1679
# 46   E06000050  Cheshire West and Chester  353097  363145 -2.70298  53.1634
# 47   E06000051                 Shropshire  350227  302960 -2.73667  52.6221
# 138  E07000117                    Burnley  384886  430882 -2.23080  53.7741
# 139  E07000118                    Chorley  359189  419724 -2.61921  53.6724
# ...

# %%
cluster_elements['LAD22NM'].values.tolist()
# Out:
# ['Halton',
#  'Warrington',
#  'Blackburn with Darwen',
#  'Blackpool',
#  'Telford and Wrekin',
#  'Stoke-on-Trent',
#  'Cheshire East',
#  'Cheshire West and Chester',
#  'Shropshire',
#  'Burnley',
#  'Chorley',
#  'Fylde',
#  'Hyndburn',
#  'Pendle',
#  'Preston',
#  'Ribble Valley',
#  'Rossendale',
#  'South Ribble',
#  'West Lancashire',
#  'Wyre',
#  'Craven',
#  'Newcastle-under-Lyme',
#  'Bolton',
#  'Bury',
#  'Manchester',
#  'Oldham',
#  'Rochdale',
#  'Salford',
#  'Stockport',
#  'Tameside',
#  'Trafford',
#  'Wigan',
#  'Knowsley',
#  'Liverpool',
#  'St. Helens',
#  'Sefton',
#  'Wirral',
#  'Calderdale',
#  'Flintshire',
#  'Wrexham']

# %%
# number of dwellings in the zonal model
Zonal_ndgs_cluster0={
    'Kingston upon Hull, City of':122723, 
    'East Riding of Yorkshire':163065,
       'North East Lincolnshire':75511, 
    'North Lincolnshire':77262,
    'Rutland':17869,
       'Peterborough':86789, 
    'North Northamptonshire':153857, 
    'Fenland':45998,
       'Huntingdonshire':78943,
    'Melton':23829, 
    'Boston':30755,
    'East Lindsey':69034, 
    'Lincoln':44900,
       'North Kesteven':52600, 
    'South Holland':42307, 
    'South Kesteven':64926,
       'West Lindsey':43722
   }
Zonal_ndgs_cluster1={
    'Leicester':139614,
    'West Northamptonshire':176807, 
    'South Derbyshire':47677,
    'Cheltenham':56943, 
    'Cotswold':45628, 
    'Tewkesbury':43327, 
    'Blaby':44251, 
    'Harborough':41771,
    'Hinckley and Bosworth':51303, 
    'North West Leicestershire':46969,
    'Oadby and Wigston':23644, 
    'Cherwell':68826,
    'West Oxfordshire':50874,
    'Cannock Chase':45012, 
    'East Staffordshire':54084,
    'Lichfield':47054,
    'South Staffordshire':48064, 
    'Stafford':63509, 
    'Tamworth':34263,
    'North Warwickshire':28858,
    'Nuneaton and Bedworth':58417, 
    'Rugby':48816,
    'Stratford-on-Avon':63548, 
    'Warwick':66909, 
    'Bromsgrove':42059, 
    'Malvern Hills': 37109, 
    'Redditch': 37676, 
    'Worcester':46599, 
    'Wychavon': 59772, 
    'Wyre Forest': 47499, 
    'Birmingham': 448812,
    'Coventry':144939, 
    'Dudley': 140519, 
    'Sandwell':133739, 
    'Solihull': 93724, 
    'Walsall': 117008, 
    'Wolverhampton': 112202
}

Zonal_ndgs_cluster2= {
    'East Cambridgeshire':38710, 'Braintree':67342, 'Colchester':83268, 'Tendring':71688,
       'Breckland':62845, 'Broadland':60024, 'Great Yarmouth':46841,
       "King's Lynn and West Norfolk":78214, 'North Norfolk':57497, 'Norwich':67104,
       'South Norfolk':63713, 'Babergh':42064, 'Ipswich':62097, 'Mid Suffolk':46594,
       'East Suffolk':119573, 'West Suffolk':81290}
Zonal_ndgs_cluster3={
    'Herefordshire, County of':87547, 'Bath and North East Somerset':84019,
       'Bristol, City of':203561, 'North Somerset':99019, 'South Gloucestershire':123113,
       'Dorset':183455, 'Forest of Dean':39144, 'Gloucester':57783, 'Stroud':55054, 'Mendip':53113,
       'Sedgemoor':56222, 'South Somerset':79838, 'Cardiff':156264, 'Caerphilly':31371,
       'Blaenau Gwent':31371, 'Torfaen':40813, 'Monmouthshire':40712, 'Newport':66543
}
Zonal_ndgs_cluster4={
    'Luton':81289, 'Slough':56773, 'Windsor and Maidenhead':65214, 'Milton Keynes':117306,
       'Brighton and Hove':129321, 'Bedford':77884, 'Central Bedfordshire':126104,
       'Buckinghamshire':230039, 'Cambridge':56091, 'South Cambridgeshire':70014, 'Lewes':46449,
       'Epping Forest':57186, 'Harlow':39358, 'Uttlesford':38833, 'Broxbourne':41368, 'Dacorum':66990,
       'Hertsmere':45240, 'North Hertfordshire':58497, 'Three Rivers':38229, 'Watford':40836,
       'Sevenoaks':51163, 'Elmbridge':58548, 'Epsom and Ewell':32880, 'Guildford':59705,
       'Mole Valley':39206, 'Reigate and Banstead':62233, 'Runnymede':37095, 'Spelthorne':43602,
       'Surrey Heath':37163, 'Tandridge':36923, 'Woking':43270, 'Adur':28730, 'Crawley':47179,
       'Horsham':65199, 'Mid Sussex':66601, 'Worthing':51324, 'St Albans':62000,
       'Welwyn Hatfield':48881, 'East Hertfordshire':64771, 'Stevenage':37828,
       'City of London':7305, 'Barking and Dagenham':77618, 'Barnet':157186, 'Bexley':99231,
       'Brent':33925, 'Bromley':140441, 'Camden':107092, 'Croydon':164746, 'Ealing':138794, 'Enfield':127472,
       'Greenwich':118492, 'Hackney':113174, 'Hammersmith and Fulham':91756, 'Haringey':111685,
       'Harrow':93884, 'Havering':103453, 'Hillingdon':113098, 'Hounslow':105106, 'Islington':105148,
       'Kensington and Chelsea':88504, 'Kingston upon Thames':68734, 'Lambeth':144222,
       'Lewisham':129547, 'Merton':85559, 'Newham':122160, 'Redbridge':107753,
       'Richmond upon Thames':87239, 'Southwark':138732, 'Sutton':84439, 'Tower Hamlets':129351,
       'Waltham Forest':105820, 'Wandsworth':150805, 'Westminster':127002
}

Zonal_ndgs_cluster5={
    'Southend-on-Sea':81652, 'Thurrock':68785, 'Medway':117366, 'Eastbourne':49355, 'Hastings':44647,
       'Rother':117521, 'Wealden':71787, 'Basildon':78809, 'Brentwood':33925, 'Castle Point':39073,
       'Chelmsford':78724, 'Maldon':29451, 'Rochford':36676, 'Ashford':56200, 'Canterbury':69135,
       'Dartford':48455, 'Dover':55439, 'Gravesham':43973, 'Maidstone':74866,
       'Folkestone and Hythe':53217, 'Swale':63379, 'Thanet':68400, 'Tonbridge and Malling':56096,
       'Tunbridge Wells':52503
}
Zonal_ndgs_cluster6={
    'Swindon':100269, 'Bracknell Forest':52915, 'West Berkshire':69438, 'Reading':71305,
       'Wokingham':71109, 'Portsmouth':91230, 'Southampton':109201, 'Isle of Wight':71426,
       'Wiltshire':224194, 'Bournemouth, Christchurch and Poole':186252,
       'Basingstoke and Deane':78761, 'East Hampshire':54804, 'Eastleigh':59745, 'Fareham':50602,
       'Gosport':38118, 'Hart':41307, 'Havant':56340, 'New Forest':82991, 'Rushmoor':40822,
       'Test Valley':57093, 'Winchester':54180, 'Oxford':59843, 'South Oxfordshire':64511,
       'Vale of White Horse':61088, 'Waverley':55029, 'Arun':276423, 'Chichester':58695
}

Zonal_ndgs_cluster7={
    'Plymouth':120780, 'Torbay':67301, 'Cornwall':286175, 'East Devon':72105, 'Exeter':57096,
       'Mid Devon':37577, 'North Devon':49182, 'South Hams':46933, 'Teignbridge':63723,
       'Torridge':33387, 'West Devon':26300, 'Somerset West and Taunton':73945
}
Zonal_ndgs_cluster8={'Isles of Scilly':1406}
Zonal_ndgs_cluster9={
    'Ceredigion':31413, 'Pembrokeshire':56647, 'Carmarthenshire':82897, 'Swansea':109714,
       'Neath Port Talbot':62768, 'Bridgend':63152, 'Vale of Glamorgan':58879,
       'Rhondda Cynon Taf':106316, 'Powys':60240, 'Merthyr Tydfil':24974
}
Zonal_ndgs_cluster10={
    'Isle of Anglesey':31555, 'Gwynedd':55123, 'Conwy':53351, 'Denbighshire':42220
}
Zonal_ndgs_cluster11={
    'Highland':110743
}

Zonal_ndgs_cluster12={
    'Moray':43590,
     'Aberedeen City':108844,
     'Aberedeenshire':113861,
     'Angus':42384,
     'Dundee City':71224
}
Zonal_ndgs_cluster13={
    'Dumfries and Galloway':70405, 'East Ayrshire':56149, 'East Renfrewshire':40081,
       'South Lanarkshire':149864, 'Stirling':40174, 'Renfrewshire':87910,
       'West Dunbartonshire':43364, 'East Dunbartonshire':46849, 'Glasgow City':298847 ,
       'North Lanarkshire':153643
}
Zonal_ndgs_cluster14={
    'Inverclyde':37958, 'North Ayrshire':64886, 'South Ayrshire':52753,
       'Argyll and Bute':42384
}
Zonal_ndgs_cluster15={
    'Clackmannanshire':24077, 'East Lothian':48400, 'Falkirk':73375, 'Midlothian':40876,
       'Scottish Borders':55296, 'City of Edinburgh':241658, 'West Lothian':80932, 'Fife':171086,
       'Perth and Kinross':70315
}
Zonal_ndgs_cluster16={
    'Allerdale':48314, 'Barrow-in-Furness':33707, 'Carlisle':54758, 'Copeland':33705, 'Eden':27453,
       'South Lakeland':56295, 'Lancaster':64641
}
Zonal_ndgs_cluster17={
    'Hartlepool':44666, 'Middlesbrough':64362, 'Redcar and Cleveland':65393,
       'Stockton-on-Tees':88607, 'Darlington':52397, 'County Durham':246445,
       'Northumberland':159916, 'Hambleton':43676, 'Harrogate':74934, 'Richmondshire':24347,
       'Ryedale':27436, 'Scarborough':60259, 'Newcastle upon Tyne':134325, 'North Tyneside':100611,
       'South Tyneside':72535, 'Sunderland':130022, 'Gateshead':94950
}
Zonal_ndgs_cluster18={
    'York':91209, 'Derby':11766, 'Nottingham':141884, 'Amber Valley':59087, 'Bolsover':37039,
       'Chesterfield':5027, 'Derbyshire Dales':35999, 'Erewash':52840, 'High Peak':43183,
       'North East Derbyshire':46888, 'Charnwood':77466, 'Selby':40877, 'Ashfield':56760,
       'Bassetlaw':53651, 'Broxtowe':50459, 'Gedling':53563, 'Mansfield':49962,
       'Newark and Sherwood':55759, 'Rushcliffe':51838, 'Staffordshire Moorlands':45068,
       'Barnsley':113022, 'Doncaster':139758, 'Rotherham':117521, 'Sheffield':253737, 'Bradford':217892,
       'Kirklees':191334, 'Leeds':356807, 'Wakefield':160281
}
Zonal_ndgs_cluster19={
    'Halton':59327, 'Warrington':93631, 'Blackburn with Darwen':62074, 'Blackpool':70683,
       'Telford and Wrekin':78590, 'Stoke-on-Trent':117690, 'Cheshire East':163258,
       'Cheshire West and Chester':163258, 'Shropshire':149250, 'Burnley':41479, 'Chorley':52563,
       'Fylde':40746, 'Hyndburn':37233, 'Pendle':40918, 'Preston':65756, 'Ribble Valley':28360,
       'Rossendale':32332, 'South Ribble':50995, 'West Lancashire':51278, 'Wyre':53346, 'Craven':28999,
       'Newcastle-under-Lyme':57657, 'Bolton':125454, 'Bury':84508, 'Manchester':235024, 'Oldham':96645,
       'Rochdale':94873, 'Salford':126281, 'Stockport':131488, 'Tameside':103835, 'Trafford':101840,
       'Wigan':149783, 'Knowsley':68426, 'Liverpool':233867, 'St. Helens':84747, 'Sefton':128400, 'Wirral':150300,
       'Calderdale':96096, 'Flintshire':66973, 'Wrexham':59058
}

# %%
# list the 20 clusters 
ndgs_clusters=[
    Zonal_ndgs_cluster0,
    Zonal_ndgs_cluster1,
    Zonal_ndgs_cluster2,
    Zonal_ndgs_cluster3,
    Zonal_ndgs_cluster4,
    Zonal_ndgs_cluster5,
    Zonal_ndgs_cluster6,
    Zonal_ndgs_cluster7,
    Zonal_ndgs_cluster8,
    Zonal_ndgs_cluster9,
    Zonal_ndgs_cluster10,
    Zonal_ndgs_cluster11,
    Zonal_ndgs_cluster12,
    Zonal_ndgs_cluster13,
    Zonal_ndgs_cluster14,
    Zonal_ndgs_cluster15,
    Zonal_ndgs_cluster16,
    Zonal_ndgs_cluster17,
    Zonal_ndgs_cluster18,
    Zonal_ndgs_cluster19
]

# find the total number of buildings per cluster
bdgs_per_cluster = []

for i in range(20):
    ndgs_i = sum(ndgs_clusters[i].values())
    bdgs_per_cluster.append(ndgs_i)
    
bdgs_per_cluster
# Out:
# [1194090,
#  2857825,
#  1048864,
#  1488942,
#  6036795,
#  1489434,
#  2237691,
#  934504,
#  1406,
#  657000,
#  182249,
#  110743,
#  379903,
#  987286,
#  197981,
#  806015,
#  318873,
#  1484881,
#  2610677,
#  3677021]
